# %% [markdown]
# # Let's query "thefork"
# The sole purpose of this notebook is to prove that we know how to query the PostgresSQL database and that the `monthly_restaurants_report.csv` CSV file has been inserted into its own table.

# %% [markdown]
# ### 🔌 Database connection

# %%
from sql import db  # <- this is from /src/sql/db.py

# %% [markdown]
# We can connect to the 'thefork' database in one line :

# %%
engine = db.connect()
engine.connect();

# %% [markdown]
# ### 🔎 Check table
# Display the first 5 rows of the `monthly_restaurants_report` table.

# %%
import pandas as pd

pd.read_sql('SELECT * FROM monthly_restaurants_report limit 5', con=engine)
